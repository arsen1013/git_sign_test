# %% [markdown]
# install pip yfinance as yf

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ## 특정 회사의 정보 다운로드

# %%
yf.download('AAPL', start='2019-01-01') #애플, 2019-01-01 정보
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31   39.632500   39.840000   39.119999   39.435001   38.233902
# 2019-01-02   38.722500   39.712502   38.557499   39.480000   38.277519
# 2019-01-03   35.994999   36.430000   35.500000   35.547501   34.464794
# 2019-01-04   36.132500   37.137501   35.950001   37.064999   35.936081
# 2019-01-07   37.174999   37.207500   36.474998   36.982498   35.856091
# ...                ...         ...         ...         ...         ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  150.619995
# 2022-03-15  150.899994  155.570007  150.380005  155.089996  155.089996
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  159.589996
# 2022-03-17  158.610001  161.000000  157.630005  160.619995  160.619995
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
#
#                Volume
# Date
# ...

# %% [markdown]
# ### 여러 회사 동시에 출력하기

# %%
yf.download(["AAPL","TSLA","AMZN"], start="2019-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed
#              Adj Close                                Close               \
#                   AAPL         AMZN        TSLA        AAPL         AMZN
# Date
# 2018-12-31   38.233898  1501.969971   66.559998   39.435001  1501.969971
# 2019-01-02   38.277523  1539.130005   62.023998   39.480000  1539.130005
# 2019-01-03   34.464798  1500.280029   60.071999   35.547501  1500.280029
# 2019-01-04   35.936077  1575.390015   63.537998   37.064999  1575.390015
# 2019-01-07   35.856091  1629.510010   66.991997   36.982498  1629.510010
# ...                ...          ...         ...         ...          ...
# 2022-03-14  150.619995  2837.060059  766.369995  150.619995  2837.060059
# 2022-03-15  155.089996  2947.330078  801.890015  155.089996  2947.330078
# 2022-03-16  159.589996  3062.080078  840.229980  159.589996  3062.080078
# 2022-03-17  160.619995  3144.780029  871.599976  160.619995  3144.780029
# ...

# %% [markdown]
# 컬럼이 독특하게 세 줄로 되어있다.
# 여기의 DAte는 index고
# AAPL, AMZN, TSLA는 상위 컬럼의 하위 종속 컬럼이다.
#
# 상위 컬럼 하나만 출력하면 하위 컬럼을 동시에 뽑을 수 있다.

# %%
data = yf.download(["AAPL","TSLA","AMZN","CPNG"], start="2019-01-01")
data['Close']
# Out:
# [*********************100%***********************]  4 of 4 completed
#                   AAPL         AMZN       CPNG        TSLA
# Date
# 2018-12-31   39.435001  1501.969971        NaN   66.559998
# 2019-01-02   39.480000  1539.130005        NaN   62.023998
# 2019-01-03   35.547501  1500.280029        NaN   60.071999
# 2019-01-04   37.064999  1575.390015        NaN   63.537998
# 2019-01-07   36.982498  1629.510010        NaN   66.991997
# ...                ...          ...        ...         ...
# 2022-03-14  150.619995  2837.060059  16.120001  766.369995
# 2022-03-15  155.089996  2947.330078  15.450000  801.890015
# 2022-03-16  159.589996  3062.080078  18.090000  840.229980
# 2022-03-17  160.619995  3144.780029  19.200001  871.599976
# 2022-03-18  163.979996  3225.010010  19.240000  905.390015
#
# [811 rows x 4 columns]

# %% [markdown]
# 2018 년엔 상장을 안 한 CPANG(쿠팡)의 경우 nan값이 나온다.

# %% [markdown]
# ## Ticker 로 각종 정보 출력하기
#
#  yf.Ticker("AAPL") 에서 Ticker 는 클래스다.
#  aapl 이라는 회사 명을 인자로 받으면 클래스 내부의 뭔가의 메소드가 실행 될 것이다.
#  다른 주식을 받고 싶으면 다른 주식을 받아 변수에 저장하면 된다.
#  이런 식으로 클래스를 활용하면 된다.

# %%
aapl = yf.Ticker("AAPL") #클래스 선언. 애플 주식을 변수에 저장

# %%
aapl.dividends #배당내역
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2021-02-05    0.205000
# 2021-05-07    0.220000
# 2021-08-06    0.220000
# 2021-11-05    0.220000
# 2022-02-04    0.220000
# Name: Dividends, Length: 74, dtype: float64

# %%
aapl.splits #주식 분할
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# 2014년 애플의 주가가 아주 급성장 해서 액면분할 1/7을 했었다.
# 그 사실을 알 수 있다.

# %%
#애널리스트의 평가정보 
aapl.recommendations
# Out:
#                                     Firm      To Grade From Grade Action
# Date
# 2012-02-09 08:17:00    Canaccord Genuity           Buy              main
# 2012-03-08 07:33:00       FBN Securities    Outperform              main
# 2012-03-13 06:08:00            Jefferies           Buy              main
# 2012-03-14 06:13:00       Morgan Stanley    Overweight              main
# 2012-03-14 08:21:00    Canaccord Genuity           Buy              main
# ...                                  ...           ...        ...    ...
# 2022-01-28 14:19:01  New Street Research       Neutral       Sell     up
# 2022-01-28 15:10:56          Oppenheimer    Outperform              main
# 2022-01-31 15:44:19        Credit Suisse       Neutral              main
# 2022-02-15 15:31:58    Tigress Financial    Strong Buy              main
# 2022-03-11 11:57:08             Barclays  Equal-Weight              main
#
# [831 rows x 4 columns]

# %% [markdown]
# 야후 파이넨스의 정보를 가져오다 보니까 애널리스트의 평가정보도 함께 나온다.

# %%
#회사 정보 확인 
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %% [markdown]
# 딕셔너리 형태로 긴 정보를 불러온다.

# %%
aapl.history(period='MAX') #전체흐름
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100323    0.100759    0.100323    0.100323  469033600
# 1980-12-15    0.095525    0.095525    0.095089    0.095089  175884800
# 1980-12-16    0.088546    0.088546    0.088110    0.088110  105728000
# 1980-12-17    0.090291    0.090727    0.090291    0.090291   86441600
# 1980-12-18    0.092908    0.093345    0.092908    0.092908   73449600
# ...                ...         ...         ...         ...        ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  108732100
# 2022-03-15  150.899994  155.570007  150.380005  155.089996   92964300
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  102300200
# 2022-03-17  158.610001  161.000000  157.630005  160.619995   75615400
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  123351200
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
cpang = yf.Ticker('CPNG') #쿠팡을 인자로 받은 클래스 생성

# %%
cpang.info
# Out:
# {'zip': '05510',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 68000,
#  'longBusinessSummary': 'Coupang, Inc. owns and operates in e-commerce business through its mobile applications and Internet websites primarily in South Korea. It operates through two segments, Product Commerce and Growth Initiatives. The company sells various products and services in the categories of home goods and dÃ©cor products, apparel, beauty products, fresh food and groceries, sporting goods, electronics, and everyday consumables, as well as travel, and restaurant order and delivery services. It also performs operations and support services in China, Singapore, Japan, Taiwan, and the United States. Coupang, Inc. was incorporated in 2010 and is headquartered in Seoul, South Korea.',
#  'city': 'Seoul',
#  'phone': '82 2 6150 5422',
#  'country': 'South Korea',
#  'companyOfficers': [],
#  'website': 'https://www.coupang.com',
#  'maxAge': 1,
#  'address1': 'Tower 730,570',
# ...

# %%
pd.DataFrame(cpang.info)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# dick 형태이므로 DataFrame으로 변경 가능하지만 값이 컬럼이 너무 많은 탓인지 바로 적용 되지는 않는다.
# 이렇게 컬럼이 많고 인덱스가 데이터가 pd.Series() 로 한번 변형해서 보는 것이 더 좋다.

# %%
pd.Series(cpang.info)
# Out:
# zip                                                                05510
# sector                                                 Consumer Cyclical
# fullTimeEmployees                                                  68000
# longBusinessSummary    Coupang, Inc. owns and operates in e-commerce ...
# city                                                               Seoul
#                                              ...
# bidSize                                                             1000
# dayHigh                                                            19.92
# regularMarketPrice                                                 19.24
# preMarketPrice                                                      None
# logo_url                           https://logo.clearbit.com/coupang.com
# Length: 151, dtype: object

# %%
result = pd.Series(cpang.info)
pd.DataFrame(result)
# Out:
#                                                                      0
# zip                                                              05510
# sector                                               Consumer Cyclical
# fullTimeEmployees                                                68000
# longBusinessSummary  Coupang, Inc. owns and operates in e-commerce ...
# city                                                             Seoul
# ...                                                                ...
# bidSize                                                           1000
# dayHigh                                                          19.92
# regularMarketPrice                                               19.24
# preMarketPrice                                                    None
# logo_url                         https://logo.clearbit.com/coupang.com
#
# [151 rows x 1 columns]

# %%
cpang.history(period='MAX')
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-03-11  63.500000  69.000000  49.250000  49.250000  91584100          0
# 2021-03-12  52.540001  52.759998  46.250000  48.470001  30521000          0
# 2021-03-15  50.130001  51.849998  49.020000  50.450001  17387800          0
# 2021-03-16  50.590000  50.770000  46.700001  47.130001  14552400          0
# 2021-03-17  46.000000  46.900002  43.189999  43.290001  15251100          0
# ...               ...        ...        ...        ...       ...        ...
# 2022-03-14  17.040001  17.488001  15.920000  16.120001  17621600          0
# 2022-03-15  16.070000  16.959999  15.275000  15.450000  30197600          0
# 2022-03-16  16.000000  18.120001  15.820000  18.090000  40631500          0
# 2022-03-17  17.680000  19.245001  17.400000  19.200001  19894800          0
# 2022-03-18  18.629999  19.920000  18.490000  19.240000  16530900          0
#
#             Stock Splits
# Date
# ...

# %% [markdown]
# # pip install pyupbit
# 업비트에서 만든 라이브러리다.
# API가 없어도 바로 받아올 수 있다.

# %%
import pyupbit as upbit

# %% [markdown]
# upbit.get_tickers 는 클래스가 아니라 함수다 별도로 변수에 저장할 필요가 없다.

# %%
#KRW 로 되어있는 코인을 표시
upbit.get_tickers(fiat ='KRW')
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-LTC',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-OMG',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-REP',
#  'KRW-ADA',
#  'KRW-SBD',
#  'KRW-POWR',
#  'KRW-BTG',
#  'KRW-ICX',
#  'KRW-EOS',
#  'KRW-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLY',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'KRW-BCH',
#  'KRW-BAT',
#  'KRW-IOST',
#  'KRW-RFR',
#  'KRW-CVC',
#  'KRW-IQ',
#  'KRW-IOTA',
#  'KRW-MFT',
#  'KRW-ONG',
#  'KRW-GAS',
#  'KRW-UPP',
#  'KRW-ELF',
#  'KRW-KNC',
#  'KRW-BSV',
#  'KRW-THETA',
#  'KRW-QKC',
#  'KRW-BTT',
#  'KRW-MOC',
#  'KRW-ENJ',
#  'KRW-TFUEL',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'KRW-AERGO',
#  'KRW-ATOM',
#  'KRW-TT',
#  'KRW-CRE',
#  'KRW-MBL',
#  'KRW-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'KRW-MLK',
#  'KRW-STPT',
#  'KRW-ORBS',
#  'KRW-VET',
#  'KRW-CHZ',
#  'KRW-STMX',
# ...

# %%
#현재가 출력
upbit.get_current_price(["KRW-BTC","KRW-ETH"])
# Out:
# {'KRW-BTC': 50130000.0, 'KRW-ETH': 3514000.0}

# %%
ticker = 'KRW-BTC'
interval = "minyte" #1분 단위로 받아오기 
to = "2022-01-01 00:00" #데이터 마지막 날
count = 100
upbit.get_ohlcv(ticker=ticker, interval = interval, to = to, count = count)
# Out:
#                            open        high         low       close  \
# 2021-09-23 09:00:00  53853000.0  54656000.0  52571000.0  54410000.0
# 2021-09-24 09:00:00  54405000.0  54534000.0  50900000.0  52176000.0
# 2021-09-25 09:00:00  52176000.0  52452000.0  51056000.0  52326000.0
# 2021-09-26 09:00:00  52326000.0  53607000.0  50803000.0  52798000.0
# 2021-09-27 09:00:00  52798000.0  53800000.0  51747000.0  51834000.0
# ...                         ...         ...         ...         ...
# 2021-12-27 09:00:00  61467000.0  62500000.0  60934000.0  61508000.0
# 2021-12-28 09:00:00  61470000.0  61508000.0  57912000.0  58274000.0
# 2021-12-29 09:00:00  58261000.0  58763000.0  56650000.0  57089000.0
# 2021-12-30 09:00:00  57089000.0  58233000.0  56400000.0  57200000.0
# 2021-12-31 09:00:00  57233000.0  58812000.0  56233000.0  56784000.0
#
#                            volume         value
# 2021-09-23 09:00:00   7737.699335  4.153849e+11
# 2021-09-24 09:00:00  11468.264849  6.029527e+11
# ...

# %%
ticker = 'KRW-BTC'
interval = "week" #주 단위로 받아오기 
count = 100
upbit.get_ohlcv(ticker=ticker,interval = interval)
# Out:
#                            open        high         low       close  \
# 2018-05-28 09:00:00   8182000.0   8443000.0   7813000.0   8419000.0
# 2018-06-04 09:00:00   8419000.0   8490000.0   7425000.0   7576000.0
# 2018-06-11 09:00:00   7576000.0   7685000.0   6951000.0   7218000.0
# 2018-06-18 09:00:00   7231000.0   7649000.0   6622000.0   6992000.0
# 2018-06-25 09:00:00   6985000.0   7290000.0   6590000.0   7109000.0
# ...                         ...         ...         ...         ...
# 2022-02-21 09:00:00  47133000.0  49010000.0  42580000.0  46358000.0
# 2022-02-28 09:00:00  46363000.0  54829000.0  46086000.0  47745000.0
# 2022-03-07 09:00:00  47782000.0  52300000.0  46525000.0  47510000.0
# 2022-03-14 09:00:00  47500000.0  51350000.0  47186000.0  50462000.0
# 2022-03-21 09:00:00  50471000.0  50756000.0  49832000.0  50130000.0
#
#                            volume         value
# 2018-05-28 09:00:00  35402.938083  2.913398e+11
# 2018-06-04 09:00:00  25886.893761  2.115380e+11
# ...

# %% [markdown]
# ## 데이터 튜닝 하기
# 1. 주식, 코인 데이터 선택,  데이터의 갯수는 1000개 선택
# 2. 데이터를 csv로 변환
# 3. csv를 db에 삽입
# 4. mysql query 데이터를 받아오기(Module 생성, class로 구현)
# 5. 주식의 기준 -> 시가, 종가, 고가,저가 소수점 2번째 자리까지 유지, 셋째 자리 반올림
# 6. 코인의 기준 -> 볼륨, 소수점 2번째 자리까지 유지 반올림
# 7. 주식 기준 nan 값 -> 2020년 1월 1일부터 ~ 라면 그 전 데이터는 시작하는 값을 넣는다.
# 8. 컬럼을 하나 추가 '등락폭(종가 - 시가)'의 값을 삽입
# 9. 컬럼 하나 추가 (등락폭 / 시가 *100 ) 퍼센트를 삽입
# 10. 데이터의 시각화 -> 시가  / 종가 / 등락폭 / 볼륨 그래프 4개를 subplot 나눠서 표시

# %% [markdown]
# ### 1. 삼성생명 데이터 선택해서 1000개 출력

# %%
s_life= yf.Ticker('032830.KS')
s_life
# Out:
# yfinance.Ticker object <032830.KS>

# %%
result = s_life.history(period="MAX").tail(1000)

# %% [markdown]
# ### 2. 삼성생명 데이터 csv 변환

# %%
result.to_csv('s_life.csv')

# %% [markdown]
# ### 3. csv를 db에 삽입

# %%
import pymysql 
import pandas as pd

# %%
_db = pymysql.connect(
    user = "root",
    host = "localhost",
    password="pw0426!",
    db = "ubion",
    charset='utf8'
)

# %%
cursor = _db.cursor(pymysql.cursors.DictCursor)

# %%
sql_1 = """
        CREATE TABLE samsung_life
        (
        Open DOUBLE,
        High DOUBLE,
        Low DOUBLE,
        Close DOUBLE,
        Adj Close, DOUBLE,
        Volume INT
        ) 
        """
cursor.execute(sql_1)
result = cursor.fetchall()
print(result)

# %% [markdown]
# 직접 작성하는 것은 너무 불편하다.
# 직접 워크벤치에서 csv를 불러와서 만진 다음에 다시 파이선에서 불러오는 것이 좋다.

# %% [markdown]
# 4. mysql query 데이터를 받아오기(Module 생성, class로 구현)

# %%
import mod_sql

# %%
_sql2 = """
        CREATE INTO 

        
         )
        """
for i in range(len(result)):
        _db.execute(_sql2,
        result.index[i],
        result.Open[i],
        result.High[i],
        result.Low[i],
        result.Close[i])

# %%
_sql2 = """
        INSERT INTO s_lif2 VALUES()
         # %s, %s, %s, %s, %s
         )
        """
for i in range(len(result)):
        #execute를 100번 한 것이다
        _db.execute(_sql2,
        result.index[i],
        result.Open[i],
        result.High[i],
        result.Low[i],
        result.Close[i])
_db.commit()

# %% [markdown]
# csv 파일을 워크벤치에서 옮기는 방법
# 1. 워크벤치에서 데이터베이스 우클릭 -> table data import
# 2. 다운로드 받은 파일 경로 찾아서 데이터 타입 맞춰주고 next, next ...

# %% [markdown]
# 5. 주식의 기준 -> 시가, 종가, 고가,저가 소수점 2번째 자리까지 유지, 셋째 자리 반올림

# %%
_db = mod_sql.Database()

# %%
_sql = """
        SELECT * FROM s_life
        """
result = _db.executeAll(_sql)
_df = pd.DataFrame(result)
_df
# Out:
#            Date           Open           High            Low          Close  \
# 0    2018-02-23  107451.547607  110917.726562  107451.547607  110917.726562
# 1    2018-02-26  110917.725490  111784.270221  108318.091299  110484.453125
# 2    2018-02-27  109184.642149  110051.186928  106585.007813  106585.007812
# 3    2018-02-28  106585.004630  107018.277006  105285.187500  105285.187500
# 4    2018-03-02  104418.639551  104851.911914  103118.822461  103985.367188
# ..          ...            ...            ...            ...            ...
# 995  2022-03-15   59800.000000   60300.000000   59300.000000   59800.000000
# 996  2022-03-16   60100.000000   61200.000000   59500.000000   61200.000000
# 997  2022-03-17   61700.000000   62600.000000   61700.000000   62300.000000
# 998  2022-03-18   61700.000000   62700.000000   61500.000000   62600.000000
# 999  2022-03-21   62700.000000   63000.000000   61800.000000   62100.000000
#
#      Volume  Dividends  Stock Splits
# ...

# %%
_df = _df.round(2)
_df
# Out:
#            Date       Open       High        Low      Close  Volume  \
# 0    2018-02-23  107451.55  110917.73  107451.55  110917.73  309916
# 1    2018-02-26  110917.73  111784.27  108318.09  110484.45  189146
# 2    2018-02-27  109184.64  110051.19  106585.01  106585.01  267401
# 3    2018-02-28  106585.00  107018.28  105285.19  105285.19  274305
# 4    2018-03-02  104418.64  104851.91  103118.82  103985.37  180757
# ..          ...        ...        ...        ...        ...     ...
# 995  2022-03-15   59800.00   60300.00   59300.00   59800.00  193398
# 996  2022-03-16   60100.00   61200.00   59500.00   61200.00  221832
# 997  2022-03-17   61700.00   62600.00   61700.00   62300.00  349375
# 998  2022-03-18   61700.00   62700.00   61500.00   62600.00  319653
# 999  2022-03-21   62700.00   63000.00   61800.00   62100.00  161690
#
#      Dividends  Stock Splits      등락폭   등락율
# 0          0.0             0  3466.18  3.23
# 1          0.0             0  -433.27 -0.39
# ...

# %%
_df.isna().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# 등락폭             0
# 등락율             0
# dtype: int64

# %%
_df.fillna("bfill")
# Out:
#            Date       Open       High        Low      Close  Volume  \
# 0    2018-02-23  107451.55  110917.73  107451.55  110917.73  309916
# 1    2018-02-26  110917.73  111784.27  108318.09  110484.45  189146
# 2    2018-02-27  109184.64  110051.19  106585.01  106585.01  267401
# 3    2018-02-28  106585.00  107018.28  105285.19  105285.19  274305
# 4    2018-03-02  104418.64  104851.91  103118.82  103985.37  180757
# ..          ...        ...        ...        ...        ...     ...
# 995  2022-03-15   59800.00   60300.00   59300.00   59800.00  193398
# 996  2022-03-16   60100.00   61200.00   59500.00   61200.00  221832
# 997  2022-03-17   61700.00   62600.00   61700.00   62300.00  349375
# 998  2022-03-18   61700.00   62700.00   61500.00   62600.00  319653
# 999  2022-03-21   62700.00   63000.00   61800.00   62100.00  161690
#
#      Dividends  Stock Splits      등락폭   등락율
# 0          0.0             0  3466.18  3.23
# 1          0.0             0  -433.27 -0.39
# ...

# %% [markdown]
# 6. 등락률

# %%
_df["등락폭"] = _df["Close"] - _df["Open"]
_df
# Out:
#            Date           Open           High            Low          Close  \
# 0    2018-02-23  107451.547607  110917.726562  107451.547607  110917.726562
# 1    2018-02-26  110917.725490  111784.270221  108318.091299  110484.453125
# 2    2018-02-27  109184.642149  110051.186928  106585.007813  106585.007812
# 3    2018-02-28  106585.004630  107018.277006  105285.187500  105285.187500
# 4    2018-03-02  104418.639551  104851.911914  103118.822461  103985.367188
# ..          ...            ...            ...            ...            ...
# 995  2022-03-15   59800.000000   60300.000000   59300.000000   59800.000000
# 996  2022-03-16   60100.000000   61200.000000   59500.000000   61200.000000
# 997  2022-03-17   61700.000000   62600.000000   61700.000000   62300.000000
# 998  2022-03-18   61700.000000   62700.000000   61500.000000   62600.000000
# 999  2022-03-21   62700.000000   63000.000000   61800.000000   62100.000000
#
#      Volume  Dividends  Stock Splits          등락폭
# ...

# %%
_df["등락율"] = _df["등락폭"]/_df["Open"]*100
_df
# Out:
#            Date           Open           High            Low          Close  \
# 0    2018-02-23  107451.547607  110917.726562  107451.547607  110917.726562
# 1    2018-02-26  110917.725490  111784.270221  108318.091299  110484.453125
# 2    2018-02-27  109184.642149  110051.186928  106585.007813  106585.007812
# 3    2018-02-28  106585.004630  107018.277006  105285.187500  105285.187500
# 4    2018-03-02  104418.639551  104851.911914  103118.822461  103985.367188
# ..          ...            ...            ...            ...            ...
# 995  2022-03-15   59800.000000   60300.000000   59300.000000   59800.000000
# 996  2022-03-16   60100.000000   61200.000000   59500.000000   61200.000000
# 997  2022-03-17   61700.000000   62600.000000   61700.000000   62300.000000
# 998  2022-03-18   61700.000000   62700.000000   61500.000000   62600.000000
# 999  2022-03-21   62700.000000   63000.000000   61800.000000   62100.000000
#
# ...

# %% [markdown]
# 7. 데이터 시각화

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(_df["Open"]) #index 값 기준으로 나옴 
# x값 기준으로 해야하는데

# %%
plt.subplot(2,2,1) #행은 두개, 열은 2개  
plt.plot(_df["Open"]) #시가
plt.subplot(2,2,2)
plt.plot(_df["Close"]) #종가
plt.subplot(2,2,3)
plt.plot(_df["등락폭"])
plt.subplot(2,2,4)
plt.plot(_df["등락율"]) 
plt.show()

# %%
plt.subplots(constrained_layout=True) # 서브 플롯 간격을 최적의 간격으로 벌려준다 
plt.subplot(2,2,1) #행은 두개, 열은 2개  
plt.plot(_df["Open"]) #시가
plt.subplot(2,2,2)
plt.plot(_df["Close"]) #종가
plt.subplot(2,2,3)
plt.plot(_df["등락폭"])
plt.subplot(2,2,4)
plt.plot(_df["등락율"]) 
plt.show()

# %% [markdown]
# 인덱스 500일때 무슨 일이 있었는지 확인해 보는 것이 좋을 것 같다.

# %%
_df[400:750]
# Out:
#            Date      Open      High       Low     Close  Volume  Dividends  \
# 400  2019-10-15  63349.90  63886.77  62992.00  63081.47  166405        0.0
# 401  2019-10-16  62813.04  64155.20  62186.70  62723.56  292694        0.0
# 402  2019-10-17  62723.56  63618.34  62455.13  63528.86  255544        0.0
# 403  2019-10-18  63886.77  64155.20  62634.09  62723.56  163739        0.0
# 404  2019-10-21  63260.43  63618.34  62634.09  63170.95  126013        0.0
# ..          ...       ...       ...       ...       ...     ...        ...
# 745  2021-03-09  77165.69  77930.65  75731.38  77356.93  681122        0.0
# 746  2021-03-10  76591.97  78217.51  76018.24  77548.17  438570        0.0
# 747  2021-03-11  77930.65  78886.86  75731.38  75922.62  873391        0.0
# 748  2021-03-12  76018.25  76209.49  74297.08  74488.32  569995        0.0
# 749  2021-03-15  74870.80  75922.62  74297.08  75922.62  311769        0.0
#
#      Stock Splits      등락폭   등락율
# 400             0  -268.43 -0.42
# ...

# %% [markdown]
# 2019년 10월과 21년 3월 11일 등락폭이 -1000, -2000에 다다른 것을 볼 수 있다.
